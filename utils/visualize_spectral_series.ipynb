# %%
from dataclasses import dataclass

import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_root = '../Spectral Series of AT2017gfo/'

# %%
@dataclass
class Observation:
    telescope_name: str
    time_since_merger: str
    data_file_path: str

# %% [markdown]
# The various subfolders are
#
# ```
# ../Spectral Series of AT2017gfo/0.48-0.53 - MagE & LDSS
# ../Spectral Series of AT2017gfo/0.92 days - ANU
# ../Spectral Series of AT2017gfo/1.17 days - SALT spectra
# ../Spectral Series of AT2017gfo/1.43-1.46 days - X-shooter (Sub-epoch spectra)
# ../Spectral Series of AT2017gfo/1.43-9.4 - X-shooter
# ../Spectral Series of AT2017gfo/1.43-9.4 - X-shooter/Spectra
# ../Spectral Series of AT2017gfo/1.43-9.4 - X-shooter/Spectra_Selsing
# ../Spectral Series of AT2017gfo/1.43-9.4 - X-shooter/dereddened+deredshifted_spectra
# ../Spectral Series of AT2017gfo/1.47-10.5 days - Gemini + SOAR
# ../Spectral Series of AT2017gfo/4.9 days - HST
# ```

# %%
def load_MagE_LDSS(file_path='0.48-0.53 - MagE & LDSS'):
    """
    Units are Angstroms for x-axis
    Flux in erg/s/cm^2/Angstrom
    """
    folder_path = data_root + file_path
    data = []
    for data_file in os.listdir(folder_path):
        dat = pd.read_csv(folder_path + '/' + data_file, sep='\s+', skiprows=7,
                            names = ['Wavelength', 'Flux'])
        print(f"Wavelength range in {data_file}: {np.min(dat['Wavelength'])} to {np.max(dat['Wavelength'])}")
        data.append(dat)
    return data # first one is LDSS, second is MagE

# %%
LDSS_spec, MagE_spec = load_MagE_LDSS()
# Out:
# Wavelength range in SSS17a-LDSS3-20170817_cal.flm: 3725.6 to 10101.2
# Wavelength range in SSS17a-MagE-20170817_cal.flm: 3615.0 to 6932.4

# %%
fix, ax = plt.subplots(figsize=(6,6))

ax.plot(LDSS_spec['Wavelength'], LDSS_spec['Flux'], label='LDSS $t=0.48$d') # I might be wrong in which is 0.48
ax.plot(MagE_spec['Wavelength'], MagE_spec['Flux'], label='MagE $t=0.53$d')
ax.legend()

# %%
load_epochs(data_root)
# Out:
# ../Spectral Series of AT2017gfo/0.48-0.53 - MagE & LDSS
# ../Spectral Series of AT2017gfo/0.92 days - ANU
# ../Spectral Series of AT2017gfo/1.17 days - SALT spectra
# ../Spectral Series of AT2017gfo/1.43-1.46 days - X-shooter (Sub-epoch spectra)
# ../Spectral Series of AT2017gfo/1.43-9.4 - X-shooter
# ../Spectral Series of AT2017gfo/1.43-9.4 - X-shooter/Spectra
# ../Spectral Series of AT2017gfo/1.43-9.4 - X-shooter/Spectra_Selsing
# ../Spectral Series of AT2017gfo/1.43-9.4 - X-shooter/dereddened+deredshifted_spectra
# ../Spectral Series of AT2017gfo/1.47-10.5 days - Gemini + SOAR
# ../Spectral Series of AT2017gfo/4.9 days - HST
